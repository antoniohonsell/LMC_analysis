# %% [markdown]
# ## FMNIST

# %%
import pandas as pd
import numpy as np

# Load the CSV file (adjust path since notebook is in CRH subdirectory)
csv_path = "../runs_sweep_full/mnist_mlp_reg/ep1200_lr_0.001_wd_0.0003_hd_2048-512_do_0_ls_0.05/FASHIONMNIST/full/seed_0/final_train/crh_pah_metrics.csv"
df = pd.read_csv(csv_path)

# Extract Hb_WWT linear alignment columns
linear_cols = ['epoch', 'Hb_WWT_eps_lin', 'Hb_WWT_c_lin', 'Hb_WWT_rho_fro']
linear_data = df[linear_cols].copy()
linear_data.columns = ['Epoch', 'ε_lin', 'c_lin', 'ρ_fro']

print("=" * 70)
print("LINEAR ALIGNMENT (Hb_WWT)")
print("=" * 70)
print(linear_data.to_string(index=False))
print()
# Out:
# ...
# LINEAR ALIGNMENT (Hb_WWT)
# ...
#  Epoch    ε_lin    c_lin    ρ_fro
#     60 0.626620 0.593222 0.779325
#    120 0.502082 0.483570 0.864820
#    180 0.479120 0.445656 0.877749
#    240 0.455112 0.416786 0.890434
#    300 0.436015 0.381345 0.899939
#    360 0.405407 0.378495 0.914136
#    420 0.477900 0.336380 0.878414
#    480 0.476490 0.326195 0.879180
#    540 0.497239 0.288967 0.867614
#    600 0.483270 0.293879 0.875472
#    660 0.466892 0.289524 0.884314
#    720 0.490603 0.266027 0.871383
#    780 0.487399 0.267759 0.873179
#    840 0.487748 0.261735 0.872985
#    900 0.481491 0.264905 0.876451

# %%
# Extract Hb_WWT power-law alignment columns
power_cols = ['epoch', 'Hb_WWT_powerlaw_alpha', 'Hb_WWT_powerlaw_r2', 'Hb_WWT_pow_eps', 'Hb_WWT_pow_c']
power_data = df[power_cols].copy()
power_data.columns = ['Epoch', 'α (alpha)', 'R²', 'ε_pow', 'c_pow']

print("=" * 70)
print("POWER-LAW ALIGNMENT (Hb_WWT)")
print("=" * 70)
print(power_data.to_string(index=False))
print()
# Out:
# ...
# POWER-LAW ALIGNMENT (Hb_WWT)
# ...
#  Epoch  α (alpha)       R²    ε_pow    c_pow
#     60   0.257895 0.440010 0.364354 3.649144
#    120   0.244858 0.850841 0.255201 3.044363
#    180   0.404198 0.961681 0.317203 2.377417
#    240   0.457620 0.988478 0.232741 2.246251
#    300   0.559493 0.978762 0.208571 2.035994
#    360   0.612261 0.967976 0.180986 1.978708
#    420   0.599857 0.955698 0.185023 2.197872
#    480   0.616671 0.959012 0.196500 2.202274
#    540   0.672632 0.946192 0.186428 2.056607
#    600   0.678668 0.943424 0.193617 2.129450
#    660   0.731080 0.932511 0.156403 2.133860
#    720   0.774860 0.924420 0.168368 2.016706
#    780   0.792234 0.922050 0.172276 2.041868
#    840   0.865002 0.919095 0.187117 2.005527
#    900   0.849663 0.908946 0.180798 2.029823

# %% [markdown]
# ## MNIST

# %%
import pandas as pd
import numpy as np

# Load the CSV file (adjust path since notebook is in CRH subdirectory)
csv_path = "../runs_sweep_full/mnist_mlp_reg/ep800_lr_0.001_wd_0.0003_hd_2048-512_do_0_ls_0/MNIST/full/seed_0/final_train/crh_pah_metrics.csv"
df = pd.read_csv(csv_path)

# Extract Hb_WWT linear alignment columns
linear_cols = ['epoch', 'Hb_WWT_eps_lin', 'Hb_WWT_c_lin', 'Hb_WWT_rho_fro']
linear_data = df[linear_cols].copy()
linear_data.columns = ['Epoch', 'ε_lin', 'c_lin', 'ρ_fro']

print("=" * 70)
print("LINEAR ALIGNMENT (Hb_WWT)")
print("=" * 70)
print(linear_data.to_string(index=False))
print()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[6], line 6
#       4 # Load the CSV file (adjust path since notebook is in CRH subdirectory)
#       5 csv_path = "../runs_sweep_full/mnist_mlp_reg/ep800_lr_0.001_wd_0.0003_hd_2048-512_do_0_ls_0/MNIST/full/seed_0/final_train/crh_pah_metrics.csv"
# ----> 6 df = pd.read_csv(csv_path)
#       8 # Extract Hb_WWT linear alignment columns
#       9 linear_cols = ['epoch', 'Hb_WWT_eps_lin', 'Hb_WWT_c_lin', 'Hb_WWT_rho_fro']
#
# ...
